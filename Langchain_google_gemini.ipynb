# %%
# !pip install -U langchain langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 1.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
import os

# Load your secret
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

print("Google API key loaded securely!")
# Out:
# Google API key loaded securely!

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# Create the Gemini chat model
gemini = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",  # Uses Gemini 2.5 Flash
    temperature=0.2
)

# %%
response = gemini.invoke("Hello! Please introduce yourself.")

print("Response:")
print(response.content)
# Out:
# Response:
# Hello there!
#
# I'm a large language model, trained by Google. I don't have a personal name or physical form, but you can think of me as a digital assistant or conversational AI.
#
# My purpose is to assist you with a wide variety of tasks. This includes:
#
# *   Answering questions
# *   Generating creative text formats (like poems, code, scripts, musical pieces, email, letters, etc.)
# *   Summarizing information
# *   Brainstorming ideas
# *   Translating languages
# *   And much more!
#
# So, please feel free to ask me anything or tell me what you'd like to do! How can I assist you today?
